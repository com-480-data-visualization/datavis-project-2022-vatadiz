# %%
import pandas as pd
path = "./data/rlcs-202122/winter-major/teams_g_wmajor.csv"
df = pd.read_csv(path)
df
# majorWinter[["stage"]].drop_duplicates()
list(df.team_name.drop_duplicates())
# Out:
# ['TEAM QUESO',
#  'DETONATOR',
#  'FAZE CLAN',
#  'VERSION1',
#  'NRG ESPORTS',
#  'FURIA ESPORTS',
#  'ENDPOINT',
#  'RENEGADES',
#  'G2 ESPORTS',
#  'EVIL GENIUSES',
#  'TEAM BDS',
#  'TEAM SECRET',
#  'DIGNITAS',
#  'SPACESTATION GAMING',
#  'PIONEERS']

# %%
for item in majorWinter.itertuples():
    print(item.stage)
    print(item.match_id)
    print(item.game_id)
# Out:
# Group Stage
# 62336d87da9d7ca1c7baad15
# 623b54ddda9d7ca1c7bab185
# Group Stage
# 62336d87da9d7ca1c7baad15
# 623b56d1c437fde7e02d2a9b
# Group Stage
# 62336d87da9d7ca1c7baad15
# 623b58d0da9d7ca1c7bab193
# Group Stage
# 62336d87da9d7ca1c7baad16
# 623b5660da9d7ca1c7bab18c
# Group Stage
# 62336d87da9d7ca1c7baad16
# 623b57efc437fde7e02d2aa2
# Group Stage
# 62336d87da9d7ca1c7baad16
# 623b59fdc437fde7e02d2aa9
# Group Stage
# 62336d87da9d7ca1c7baad17
# 623b60d7c437fde7e02d2ab7
# Group Stage
# 62336d87da9d7ca1c7baad17
# 623b62f1da9d7ca1c7bab1a1
# Group Stage
# 62336d87da9d7ca1c7baad17
# 623b64c0da9d7ca1c7bab1af
# Group Stage
# 62336d87da9d7ca1c7baad17
# 623b66aec437fde7e02d2abe
# Group Stage
# 62336d87da9d7ca1c7baad18
# 623b6022c437fde7e02d2ab0
# Group Stage
# 62336d87da9d7ca1c7baad18
# 623b6205da9d7ca1c7bab19a
# Group Stage
# 62336d87da9d7ca1c7baad18
# 623b63b8da9d7ca1c7bab1a8
# Group Stage
# 62336d87da9d7ca1c7baad18
# 623b6975c437fde7e02d2ac5
# Group Stage
# 62336d87da9d7ca1c7baad19
# ...
